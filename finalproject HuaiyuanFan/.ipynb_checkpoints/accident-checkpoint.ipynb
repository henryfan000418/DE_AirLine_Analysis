# %% [markdown]
# # Environment setup

# %%
# !pip install scikit-learn==1.2.2

# %%
# !pip install data_describe
# !pip install missingno

# %%
# %matplotlib inline
import data_describe as dd
import missingno as msno
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import datetime as dt
import sklearn
import pickle
import copy


from sklearn import preprocessing
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn import metrics 
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor




from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from imblearn.over_sampling import RandomOverSampler
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Import dataset

# %%
data=pd.read_csv('C:/Users/herry/Desktop/Data eng/finalproject/incident.csv',encoding='ISO-8859-1')

# %%
#View header data
data.head()
# Out:
#   Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0      3-Jan-22  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 1      4-Jan-22  British Aerospace 3101 Jetstream 31               HR-AYY
# 2      5-Jan-22                       Boeing 737-4H6               EP-CAP
# 3      8-Jan-22                  Tupolev Tu-204-100C             RA-64032
# 4     12-Jan-22        Beechcraft 200 Super King Air                  NaN
#
#            Aircaft_Operator                    Aircaft_Nature  \
# 0                SA Airlink  Domestic Non Scheduled Passenger
# 1                    LANHSA      Domestic Scheduled Passenger
# 2          Caspian Airlines      Domestic Scheduled Passenger
# 3  Cainiao, opb Aviastar-TU                             Cargo
# 4                         T                    Illegal Flight
#
#                                    Incident_Category  \
# 0                       Accident | repairable-damage
# 1                       Accident | repairable-damage
# 2                       Accident | repairable-damage
# 3                               Accident | hull-loss
# 4  Criminal occurrence (sabotage, shoot down) | h...
#
#                                   Incident_Cause(es)     Incident_Location  \
# 0  Airplane - Engines, Airplane - Engines - Prop/...  near Venetia Mine...
# 1  Airplane - Undercarriage, Airplane - Undercarr...      RoatÃ¡n-Juan ...
# 2  Airplane - Undercarriage, Airplane - Undercarr...       Isfahan-Shah...
# 3  Cargo - Fire/smoke, Result - Damaged on the gr...       Hangzhou-Xia...
# 4                     Result - Damaged on the ground       Machakilha, ...
#
#      Aircaft_Damage_Type                       Date  ...  \
# 0            Substantial      Monday 3 January 2022  ...
# 1            Substantial     Tuesday 4 January 2022  ...
# 2            Substantial   Wednesday 5 January 2022  ...
# 3              Destroyed    Saturday 8 January 2022  ...
# 4  Damaged beyond repair  Wednesday 12 January 2022  ...
#
#                    Onboard_Crew            Onboard_Passengers  \
# 0  Fatalities: 0 / Occupants: 3  Fatalities: 0 / Occupants: 4
# 1    Fatalities: 0 / Occupants:    Fatalities: 0 / Occupants:
# 2    Fatalities: 0 / Occupants:    Fatalities: 0 / Occupants:
# 3  Fatalities: 0 / Occupants: 8  Fatalities: 0 / Occupants: 0
# 4  Fatalities: 0 / Occupants: 0  Fatalities: 0 / Occupants: 0
#
#                     Onboard_Total Fatalities             Aircaft_First_Flight  \
# 0    Fatalities: 0 / Occupants: 7          0  1995-05-19  (26 years 8 months)
# 1   Fatalities: 0 / Occupants: 19          0                             1985
# 2  Fatalities: 0 / Occupants: 116          0  1992-09-18  (29 years 4 months)
# 3    Fatalities: 0 / Occupants: 8          0  2002-07-18  (19 years 6 months)
# 4    Fatalities: 0 / Occupants: 0          0                              NaN
#
#    Aircraft_Phase                                  Departure_Airport  \
# 0   Landing (LDG)  Johannesburg-O.R. Tambo International Airport ...
# 1   Landing (LDG)  La Ceiba-Goloson International Airport (LCE/MH...
# 2   Landing (LDG)                  Mashhad Airport (MHD/OIMM) , Iran
# 3  Standing (STD)  Hangzhou-Xiaoshan International Airport (HGH/Z...
# 4  Standing (STD)                                                  ?
#
#                                  Destination_Airport Ground_Casualties  \
# 0         Venetia Mine Airport (FAVM) , South Africa               NaN
# 1  RoatÃ¡n-Juan Manuel GÃ¡lvez International Airp...               NaN
# 2  Isfahan-Shahid Beheshti Airport (IFN/OIFM) , Iran               NaN
# 3  Novosibirsk-Tolmachevo Airport (OVB/UNNT) , Ru...               NaN
# 4                                                  ?               NaN
#
#   Collision_Casualties
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# # EDA

# %% [markdown]
# ## Key characteristics

# %% [markdown]
# ### data types

# %%
#View datatypes
data.dtypes
# Out:
# Incident_Date           object
# Aircaft_Model           object
# Aircaft_Registration    object
# Aircaft_Operator        object
# Aircaft_Nature          object
# Incident_Category       object
# Incident_Cause(es)      object
# Incident_Location       object
# Aircaft_Damage_Type     object
# Date                    object
# Time                    object
# Arit                    object
# Aircaft_Engines         object
# Onboard_Crew            object
# Onboard_Passengers      object
# Onboard_Total           object
# Fatalities               int64
# Aircaft_First_Flight    object
# Aircraft_Phase          object
# Departure_Airport       object
# Destination_Airport     object
# Ground_Casualties       object
# Collision_Casualties    object
# dtype: object

# %% [markdown]
# ### total rows of data

# %%
num_rows = len(data)
num_rows
# Out:
# 23519

# %% [markdown]
# ### data cleaning

# %%
columns_to_check = data.columns[data.columns.get_loc('Incident_Date'):data.columns.get_loc('Destination_Airport')+1]
columns_to_check
# Out:
# Index(['Incident_Date', 'Aircaft_Model', 'Aircaft_Registration',
#        'Aircaft_Operator', 'Aircaft_Nature', 'Incident_Category',
#        'Incident_Cause(es)', 'Incident_Location', 'Aircaft_Damage_Type',
#        'Date', 'Time', 'Arit', 'Aircaft_Engines', 'Onboard_Crew',
#        'Onboard_Passengers', 'Onboard_Total', 'Fatalities',
#        'Aircaft_First_Flight', 'Aircraft_Phase', 'Departure_Airport',
#        'Destination_Airport'],
#       dtype='object')

# %% [markdown]
# ## number of rows of problem data contains ?

# %%
## number of rows of problem data 
contains_question_mark_or_nan = data[columns_to_check].applymap(lambda x: x == '?').any(axis=1)
count_question_mark_or_nan = contains_question_mark_or_nan.sum()
count_question_mark_or_nan
# Out:
# 9824

# %% [markdown]
# ## number of rows of problem data that's na

# %%
contains_question_mark_or_nan = data[columns_to_check].applymap(lambda x: pd.isna(x)).any(axis=1)
count_question_mark_or_nan = contains_question_mark_or_nan.sum()
count_question_mark_or_nan
# Out:
# 17747

# %% [markdown]
# ## number of rows of problem data in date

# %%
missing_date_data = data[data['Incident_Date'].str.contains('\?')]

# %%
num_rows = len(missing_date_data )
num_rows
# Out:
# 507

# %%
data
# Out:
#       Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0          3-Jan-22  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 1          4-Jan-22  British Aerospace 3101 Jetstream 31               HR-AYY
# 2          5-Jan-22                       Boeing 737-4H6               EP-CAP
# 3          8-Jan-22                  Tupolev Tu-204-100C             RA-64032
# 4         12-Jan-22        Beechcraft 200 Super King Air                  NaN
# ...             ...                                  ...                  ...
# 23514     25-Feb-20                   Handley Page O/400               G-EAMC
# 23515     30-Jun-20                   Handley Page O/400               G-EAKE
# 23516     14-Dec-20                   Handley Page O/400               G-EAMA
# 23517      2-Aug-19                        Caproni Ca.48                  NaN
# 23518     11-Aug-19                      Felixstowe Fury                 N123
#
#                Aircaft_Operator                     Aircaft_Nature  \
# 0                    SA Airlink   Domestic Non Scheduled Passenger
# 1                        LANHSA       Domestic Scheduled Passenger
# 2              Caspian Airlines       Domestic Scheduled Passenger
# 3      Cainiao, opb Aviastar-TU                              Cargo
# 4                             T                     Illegal Flight
# ...                         ...                                ...
# 23514    Handley Page Transport                            Unknown
# 23515    Handley Page Transport                      Demonstration
# 23516    Handley Page Transport  International Scheduled Passenger
# 23517                   Caproni                          Passenger
# 23518                       RAF                               Test
#
#                                        Incident_Category  \
# 0                           Accident | repairable-damage
# 1                           Accident | repairable-damage
# 2                           Accident | repairable-damage
# 3                                   Accident | hull-loss
# 4      Criminal occurrence (sabotage, shoot down) | h...
# ...                                                  ...
# 23514                               Accident | hull-loss
# 23515                               Accident | hull-loss
# 23516                               Accident | hull-loss
# 23517                               Accident | hull-loss
# 23518                               Accident | hull-loss
#
#                                       Incident_Cause(es)  \
# 0      Airplane - Engines, Airplane - Engines - Prop/...
# 1      Airplane - Undercarriage, Airplane - Undercarr...
# 2      Airplane - Undercarriage, Airplane - Undercarr...
# 3      Cargo - Fire/smoke, Result - Damaged on the gr...
# 4                         Result - Damaged on the ground
# ...                                                  ...
# 23514  Result - Emergency, forced landing - Outside a...
# 23515  Result - Emergency, forced landing - Outside a...
# 23516                       Result - CFIT - Level ground
# 23517                                   Info-Unavailable
# 23518                                   Info-Unavailable
#
#           Incident_Location    Aircaft_Damage_Type  \
# 0      near Venetia Mine...            Substantial
# 1          RoatÃ¡n-Juan ...            Substantial
# 2           Isfahan-Shah...            Substantial
# 3           Hangzhou-Xia...              Destroyed
# 4           Machakilha, ...  Damaged beyond repair
# ...                     ...                    ...
# 23514       near El Shereik  Damaged beyond repair
# 23515              ÃstanÃ¥  Damaged beyond repair
# 23516         Golders Green  Damaged beyond repair
# 23517                Verona              Destroyed
# 23518   near Felixtowe RNAS  Damaged beyond repair
#
#                              Date  ...                  Onboard_Crew  \
# 0           Monday 3 January 2022  ...  Fatalities: 0 / Occupants: 3
# 1          Tuesday 4 January 2022  ...    Fatalities: 0 / Occupants:
# 2        Wednesday 5 January 2022  ...    Fatalities: 0 / Occupants:
# 3         Saturday 8 January 2022  ...  Fatalities: 0 / Occupants: 8
# 4       Wednesday 12 January 2022  ...  Fatalities: 0 / Occupants: 0
# ...                           ...  ...                           ...
# 23514  Wednesday 25 February 1920  ...  Fatalities: 0 / Occupants: 4
# 23515      Wednesday 30 June 1920  ...  Fatalities: 0 / Occupants: 2
# 23516    Tuesday 14 December 1920  ...  Fatalities: 2 / Occupants: 2
# 23517      Saturday 2 August 1919  ...  Fatalities: 2 / Occupants: 2
# 23518       Monday 11 August 1919  ...  Fatalities: 1 / Occupants: 7
#
#                    Onboard_Passengers                   Onboard_Total  \
# 0        Fatalities: 0 / Occupants: 4    Fatalities: 0 / Occupants: 7
# 1          Fatalities: 0 / Occupants:   Fatalities: 0 / Occupants: 19
# 2          Fatalities: 0 / Occupants:  Fatalities: 0 / Occupants: 116
# 3        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 8
# 4        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 0
# ...                               ...                             ...
# 23514    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 4
# 23515    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 2
# 23516    Fatalities: 2 / Occupants: 6    Fatalities: 4 / Occupants: 8
# 23517  Fatalities: 12 / Occupants: 12  Fatalities: 14 / Occupants: 14
# 23518    Fatalities: 0 / Occupants: 0    Fatalities: 1 / Occupants: 7
#
#       Fatalities             Aircaft_First_Flight       Aircraft_Phase  \
# 0              0  1995-05-19  (26 years 8 months)        Landing (LDG)
# 1              0                             1985        Landing (LDG)
# 2              0  1992-09-18  (29 years 4 months)        Landing (LDG)
# 3              0  2002-07-18  (19 years 6 months)       Standing (STD)
# 4              0                              NaN       Standing (STD)
# ...          ...                              ...                  ...
# 23514          0                              NaN        Unknown (UNK)
# 23515          0                             1919       En route (ENR)
# 23516          4                              NaN  Initial climb (ICL)
# 23517         14                             1919       En route (ENR)
# 23518          1           1918-11-11  (9 months)  Initial climb (ICL)
#
#                                        Departure_Airport  \
# 0      Johannesburg-O.R. Tambo International Airport ...
# 1      La Ceiba-Goloson International Airport (LCE/MH...
# 2                      Mashhad Airport (MHD/OIMM) , Iran
# 3      Hangzhou-Xiaoshan International Airport (HGH/Z...
# 4                                                      ?
# ...                                                  ...
# 23514                   Aswan Airport (ASW/HESN) , Egypt
# 23515               Stockholm (unknown airport) , Sweden
# 23516      London-Cricklewood Aerodrome , United Kingdom
# 23517       Venice-Marco Polo Airport (VCE/LIPZ) , Italy
# 23518                   Felixstowe RNAS , United Kingdom
#
#                                      Destination_Airport Ground_Casualties  \
# 0             Venetia Mine Airport (FAVM) , South Africa               NaN
# 1      RoatÃ¡n-Juan Manuel GÃ¡lvez International Airp...               NaN
# 2      Isfahan-Shahid Beheshti Airport (IFN/OIFM) , Iran               NaN
# 3      Novosibirsk-Tolmachevo Airport (OVB/UNNT) , Ru...               NaN
# 4                                                      ?               NaN
# ...                                                  ...               ...
# 23514          Khartoum-Civil Airport (KRT/HSSS) , Sudan               NaN
# 23515                   Kjeller Air Base (ENKJ) , Norway               NaN
# 23516       Paris-Le Bourget Airport (LBG/LFPB) , France               NaN
# 23517                     Milano-Taliedo Airport , Italy               NaN
# 23518                   Felixstowe RNAS , United Kingdom               NaN
#
#       Collision_Casualties
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 23514                  NaN
# 23515                  NaN
# 23516                  NaN
# 23517                  NaN
# 23518                  NaN
#
# [23519 rows x 23 columns]

# %% [markdown]
# ### drop datas contain ? in incident data column

# %%
data = data.drop(missing_date_data.index)

# %% [markdown]
# ## Data Profiling

# %% [markdown]
# ### drop data with bad date on it such as year 2060 or so...

# %%
import pandas as pd
from datetime import datetime

# %%
#Append new column with converted date types
def convert_date(date_string):
    try:
        # Try parsing as '%d-%b-%y' format
        return datetime.strptime(date_string, '%d-%b-%y')
    except ValueError:
        try:
            # Try parsing as 'YYYY-MM-DD' format using pd.to_datetime with format parameter
            parsed_date = pd.to_datetime(date_string, format='%Y-%m-%d')
            current_year = pd.Timestamp.today().year
            threshold_year = 50  # Set the threshold year for disambiguation
            # If the parsed year is greater than the threshold year, subtract 100 years
            if parsed_date.year > current_year % 100:
                return parsed_date - pd.DateOffset(years=100)
            else:
                return parsed_date
        except ValueError:
            return None  # Return None for invalid dates

# Convert the 'Incident_Date' column, handling different date formats by setting them to datetime or None
data['Incident_Date'] = data['Incident_Date'].apply(lambda x: convert_date(x))

# %%
# # number of rows with wrong format/ bad data record
# data_with_wrong_format

# %%
# data = data.drop(data_with_wrong_format.index)

# %%
data
# Out:
#       Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0        2022-01-03  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 1        2022-01-04  British Aerospace 3101 Jetstream 31               HR-AYY
# 2        2022-01-05                       Boeing 737-4H6               EP-CAP
# 3        2022-01-08                  Tupolev Tu-204-100C             RA-64032
# 4        2022-01-12        Beechcraft 200 Super King Air                  NaN
# ...             ...                                  ...                  ...
# 23514    2020-02-25                   Handley Page O/400               G-EAMC
# 23515    2020-06-30                   Handley Page O/400               G-EAKE
# 23516    2020-12-14                   Handley Page O/400               G-EAMA
# 23517    2019-08-02                        Caproni Ca.48                  NaN
# 23518    2019-08-11                      Felixstowe Fury                 N123
#
#                Aircaft_Operator                     Aircaft_Nature  \
# 0                    SA Airlink   Domestic Non Scheduled Passenger
# 1                        LANHSA       Domestic Scheduled Passenger
# 2              Caspian Airlines       Domestic Scheduled Passenger
# 3      Cainiao, opb Aviastar-TU                              Cargo
# 4                             T                     Illegal Flight
# ...                         ...                                ...
# 23514    Handley Page Transport                            Unknown
# 23515    Handley Page Transport                      Demonstration
# 23516    Handley Page Transport  International Scheduled Passenger
# 23517                   Caproni                          Passenger
# 23518                       RAF                               Test
#
#                                        Incident_Category  \
# 0                           Accident | repairable-damage
# 1                           Accident | repairable-damage
# 2                           Accident | repairable-damage
# 3                                   Accident | hull-loss
# 4      Criminal occurrence (sabotage, shoot down) | h...
# ...                                                  ...
# 23514                               Accident | hull-loss
# 23515                               Accident | hull-loss
# 23516                               Accident | hull-loss
# 23517                               Accident | hull-loss
# 23518                               Accident | hull-loss
#
#                                       Incident_Cause(es)  \
# 0      Airplane - Engines, Airplane - Engines - Prop/...
# 1      Airplane - Undercarriage, Airplane - Undercarr...
# 2      Airplane - Undercarriage, Airplane - Undercarr...
# 3      Cargo - Fire/smoke, Result - Damaged on the gr...
# 4                         Result - Damaged on the ground
# ...                                                  ...
# 23514  Result - Emergency, forced landing - Outside a...
# 23515  Result - Emergency, forced landing - Outside a...
# 23516                       Result - CFIT - Level ground
# 23517                                   Info-Unavailable
# 23518                                   Info-Unavailable
#
#           Incident_Location    Aircaft_Damage_Type  \
# 0      near Venetia Mine...            Substantial
# 1          RoatÃ¡n-Juan ...            Substantial
# 2           Isfahan-Shah...            Substantial
# 3           Hangzhou-Xia...              Destroyed
# 4           Machakilha, ...  Damaged beyond repair
# ...                     ...                    ...
# 23514       near El Shereik  Damaged beyond repair
# 23515              ÃstanÃ¥  Damaged beyond repair
# 23516         Golders Green  Damaged beyond repair
# 23517                Verona              Destroyed
# 23518   near Felixtowe RNAS  Damaged beyond repair
#
#                              Date  ...                  Onboard_Crew  \
# 0           Monday 3 January 2022  ...  Fatalities: 0 / Occupants: 3
# 1          Tuesday 4 January 2022  ...    Fatalities: 0 / Occupants:
# 2        Wednesday 5 January 2022  ...    Fatalities: 0 / Occupants:
# 3         Saturday 8 January 2022  ...  Fatalities: 0 / Occupants: 8
# 4       Wednesday 12 January 2022  ...  Fatalities: 0 / Occupants: 0
# ...                           ...  ...                           ...
# 23514  Wednesday 25 February 1920  ...  Fatalities: 0 / Occupants: 4
# 23515      Wednesday 30 June 1920  ...  Fatalities: 0 / Occupants: 2
# 23516    Tuesday 14 December 1920  ...  Fatalities: 2 / Occupants: 2
# 23517      Saturday 2 August 1919  ...  Fatalities: 2 / Occupants: 2
# 23518       Monday 11 August 1919  ...  Fatalities: 1 / Occupants: 7
#
#                    Onboard_Passengers                   Onboard_Total  \
# 0        Fatalities: 0 / Occupants: 4    Fatalities: 0 / Occupants: 7
# 1          Fatalities: 0 / Occupants:   Fatalities: 0 / Occupants: 19
# 2          Fatalities: 0 / Occupants:  Fatalities: 0 / Occupants: 116
# 3        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 8
# 4        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 0
# ...                               ...                             ...
# 23514    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 4
# 23515    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 2
# 23516    Fatalities: 2 / Occupants: 6    Fatalities: 4 / Occupants: 8
# 23517  Fatalities: 12 / Occupants: 12  Fatalities: 14 / Occupants: 14
# 23518    Fatalities: 0 / Occupants: 0    Fatalities: 1 / Occupants: 7
#
#       Fatalities             Aircaft_First_Flight       Aircraft_Phase  \
# 0              0  1995-05-19  (26 years 8 months)        Landing (LDG)
# 1              0                             1985        Landing (LDG)
# 2              0  1992-09-18  (29 years 4 months)        Landing (LDG)
# 3              0  2002-07-18  (19 years 6 months)       Standing (STD)
# 4              0                              NaN       Standing (STD)
# ...          ...                              ...                  ...
# 23514          0                              NaN        Unknown (UNK)
# 23515          0                             1919       En route (ENR)
# 23516          4                              NaN  Initial climb (ICL)
# 23517         14                             1919       En route (ENR)
# 23518          1           1918-11-11  (9 months)  Initial climb (ICL)
#
#                                        Departure_Airport  \
# 0      Johannesburg-O.R. Tambo International Airport ...
# 1      La Ceiba-Goloson International Airport (LCE/MH...
# 2                      Mashhad Airport (MHD/OIMM) , Iran
# 3      Hangzhou-Xiaoshan International Airport (HGH/Z...
# 4                                                      ?
# ...                                                  ...
# 23514                   Aswan Airport (ASW/HESN) , Egypt
# 23515               Stockholm (unknown airport) , Sweden
# 23516      London-Cricklewood Aerodrome , United Kingdom
# 23517       Venice-Marco Polo Airport (VCE/LIPZ) , Italy
# 23518                   Felixstowe RNAS , United Kingdom
#
#                                      Destination_Airport Ground_Casualties  \
# 0             Venetia Mine Airport (FAVM) , South Africa               NaN
# 1      RoatÃ¡n-Juan Manuel GÃ¡lvez International Airp...               NaN
# 2      Isfahan-Shahid Beheshti Airport (IFN/OIFM) , Iran               NaN
# 3      Novosibirsk-Tolmachevo Airport (OVB/UNNT) , Ru...               NaN
# 4                                                      ?               NaN
# ...                                                  ...               ...
# 23514          Khartoum-Civil Airport (KRT/HSSS) , Sudan               NaN
# 23515                   Kjeller Air Base (ENKJ) , Norway               NaN
# 23516       Paris-Le Bourget Airport (LBG/LFPB) , France               NaN
# 23517                     Milano-Taliedo Airport , Italy               NaN
# 23518                   Felixstowe RNAS , United Kingdom               NaN
#
#       Collision_Casualties
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 23514                  NaN
# 23515                  NaN
# 23516                  NaN
# 23517                  NaN
# 23518                  NaN
#
# [23012 rows x 23 columns]

# %%
msno.matrix(data,figsize = (20,6))
# Out:
# <Axes: >

# %%
dd.importance(data, 'Fatalities')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
plt.hist(data['Fatalities'])
# Out:
# (array([2.296e+04, 4.800e+01, 1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([   0. ,  169.2,  338.4,  507.6,  676.8,  846. , 1015.2, 1184.4,
#         1353.6, 1522.8, 1692. ]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.DataFrame(data)
display(df)
# Out:
#       Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0        2022-01-03  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 1        2022-01-04  British Aerospace 3101 Jetstream 31               HR-AYY
# 2        2022-01-05                       Boeing 737-4H6               EP-CAP
# 3        2022-01-08                  Tupolev Tu-204-100C             RA-64032
# 4        2022-01-12        Beechcraft 200 Super King Air                  NaN
# ...             ...                                  ...                  ...
# 23514    2020-02-25                   Handley Page O/400               G-EAMC
# 23515    2020-06-30                   Handley Page O/400               G-EAKE
# 23516    2020-12-14                   Handley Page O/400               G-EAMA
# 23517    2019-08-02                        Caproni Ca.48                  NaN
# 23518    2019-08-11                      Felixstowe Fury                 N123
#
#                Aircaft_Operator                     Aircaft_Nature  \
# 0                    SA Airlink   Domestic Non Scheduled Passenger
# 1                        LANHSA       Domestic Scheduled Passenger
# 2              Caspian Airlines       Domestic Scheduled Passenger
# 3      Cainiao, opb Aviastar-TU                              Cargo
# 4                             T                     Illegal Flight
# ...                         ...                                ...
# 23514    Handley Page Transport                            Unknown
# 23515    Handley Page Transport                      Demonstration
# 23516    Handley Page Transport  International Scheduled Passenger
# 23517                   Caproni                          Passenger
# 23518                       RAF                               Test
#
#                                        Incident_Category  \
# 0                           Accident | repairable-damage
# 1                           Accident | repairable-damage
# 2                           Accident | repairable-damage
# 3                                   Accident | hull-loss
# 4      Criminal occurrence (sabotage, shoot down) | h...
# ...                                                  ...
# 23514                               Accident | hull-loss
# 23515                               Accident | hull-loss
# 23516                               Accident | hull-loss
# 23517                               Accident | hull-loss
# 23518                               Accident | hull-loss
#
#                                       Incident_Cause(es)  \
# 0      Airplane - Engines, Airplane - Engines - Prop/...
# 1      Airplane - Undercarriage, Airplane - Undercarr...
# 2      Airplane - Undercarriage, Airplane - Undercarr...
# 3      Cargo - Fire/smoke, Result - Damaged on the gr...
# 4                         Result - Damaged on the ground
# ...                                                  ...
# 23514  Result - Emergency, forced landing - Outside a...
# 23515  Result - Emergency, forced landing - Outside a...
# 23516                       Result - CFIT - Level ground
# 23517                                   Info-Unavailable
# 23518                                   Info-Unavailable
#
#           Incident_Location    Aircaft_Damage_Type  \
# 0      near Venetia Mine...            Substantial
# 1          RoatÃ¡n-Juan ...            Substantial
# 2           Isfahan-Shah...            Substantial
# 3           Hangzhou-Xia...              Destroyed
# 4           Machakilha, ...  Damaged beyond repair
# ...                     ...                    ...
# 23514       near El Shereik  Damaged beyond repair
# 23515              ÃstanÃ¥  Damaged beyond repair
# 23516         Golders Green  Damaged beyond repair
# 23517                Verona              Destroyed
# 23518   near Felixtowe RNAS  Damaged beyond repair
#
#                              Date  ...                  Onboard_Crew  \
# 0           Monday 3 January 2022  ...  Fatalities: 0 / Occupants: 3
# 1          Tuesday 4 January 2022  ...    Fatalities: 0 / Occupants:
# 2        Wednesday 5 January 2022  ...    Fatalities: 0 / Occupants:
# 3         Saturday 8 January 2022  ...  Fatalities: 0 / Occupants: 8
# 4       Wednesday 12 January 2022  ...  Fatalities: 0 / Occupants: 0
# ...                           ...  ...                           ...
# 23514  Wednesday 25 February 1920  ...  Fatalities: 0 / Occupants: 4
# 23515      Wednesday 30 June 1920  ...  Fatalities: 0 / Occupants: 2
# 23516    Tuesday 14 December 1920  ...  Fatalities: 2 / Occupants: 2
# 23517      Saturday 2 August 1919  ...  Fatalities: 2 / Occupants: 2
# 23518       Monday 11 August 1919  ...  Fatalities: 1 / Occupants: 7
#
#                    Onboard_Passengers                   Onboard_Total  \
# 0        Fatalities: 0 / Occupants: 4    Fatalities: 0 / Occupants: 7
# 1          Fatalities: 0 / Occupants:   Fatalities: 0 / Occupants: 19
# 2          Fatalities: 0 / Occupants:  Fatalities: 0 / Occupants: 116
# 3        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 8
# 4        Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 0
# ...                               ...                             ...
# 23514    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 4
# 23515    Fatalities: 0 / Occupants: 0    Fatalities: 0 / Occupants: 2
# 23516    Fatalities: 2 / Occupants: 6    Fatalities: 4 / Occupants: 8
# 23517  Fatalities: 12 / Occupants: 12  Fatalities: 14 / Occupants: 14
# 23518    Fatalities: 0 / Occupants: 0    Fatalities: 1 / Occupants: 7
#
#       Fatalities             Aircaft_First_Flight       Aircraft_Phase  \
# 0              0  1995-05-19  (26 years 8 months)        Landing (LDG)
# 1              0                             1985        Landing (LDG)
# 2              0  1992-09-18  (29 years 4 months)        Landing (LDG)
# 3              0  2002-07-18  (19 years 6 months)       Standing (STD)
# 4              0                              NaN       Standing (STD)
# ...          ...                              ...                  ...
# 23514          0                              NaN        Unknown (UNK)
# 23515          0                             1919       En route (ENR)
# 23516          4                              NaN  Initial climb (ICL)
# 23517         14                             1919       En route (ENR)
# 23518          1           1918-11-11  (9 months)  Initial climb (ICL)
#
#                                        Departure_Airport  \
# 0      Johannesburg-O.R. Tambo International Airport ...
# 1      La Ceiba-Goloson International Airport (LCE/MH...
# 2                      Mashhad Airport (MHD/OIMM) , Iran
# 3      Hangzhou-Xiaoshan International Airport (HGH/Z...
# 4                                                      ?
# ...                                                  ...
# 23514                   Aswan Airport (ASW/HESN) , Egypt
# 23515               Stockholm (unknown airport) , Sweden
# 23516      London-Cricklewood Aerodrome , United Kingdom
# 23517       Venice-Marco Polo Airport (VCE/LIPZ) , Italy
# 23518                   Felixstowe RNAS , United Kingdom
#
#                                      Destination_Airport Ground_Casualties  \
# 0             Venetia Mine Airport (FAVM) , South Africa               NaN
# 1      RoatÃ¡n-Juan Manuel GÃ¡lvez International Airp...               NaN
# 2      Isfahan-Shahid Beheshti Airport (IFN/OIFM) , Iran               NaN
# 3      Novosibirsk-Tolmachevo Airport (OVB/UNNT) , Ru...               NaN
# 4                                                      ?               NaN
# ...                                                  ...               ...
# 23514          Khartoum-Civil Airport (KRT/HSSS) , Sudan               NaN
# 23515                   Kjeller Air Base (ENKJ) , Norway               NaN
# 23516       Paris-Le Bourget Airport (LBG/LFPB) , France               NaN
# 23517                     Milano-Taliedo Airport , Italy               NaN
# 23518                   Felixstowe RNAS , United Kingdom               NaN
#
#       Collision_Casualties
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 23514                  NaN
# 23515                  NaN
# 23516                  NaN
# 23517                  NaN
# 23518                  NaN
#
# [23012 rows x 23 columns]

# %%
df[['Incident_Type', 'Incident_Damage']] = data['Incident_Category'].str.split('|', expand=True)

# %%
df
# Out:
#       Incident_Date                        Aircaft_Model Aircaft_Registration  \
# 0        2022-01-03  British Aerospace 4121 Jetstream 41               ZS-NRJ
# 1        2022-01-04  British Aerospace 3101 Jetstream 31               HR-AYY
# 2        2022-01-05                       Boeing 737-4H6               EP-CAP
# 3        2022-01-08                  Tupolev Tu-204-100C             RA-64032
# 4        2022-01-12        Beechcraft 200 Super King Air                  NaN
# ...             ...                                  ...                  ...
# 23514    2020-02-25                   Handley Page O/400               G-EAMC
# 23515    2020-06-30                   Handley Page O/400               G-EAKE
# 23516    2020-12-14                   Handley Page O/400               G-EAMA
# 23517    2019-08-02                        Caproni Ca.48                  NaN
# 23518    2019-08-11                      Felixstowe Fury                 N123
#
#                Aircaft_Operator                     Aircaft_Nature  \
# 0                    SA Airlink   Domestic Non Scheduled Passenger
# 1                        LANHSA       Domestic Scheduled Passenger
# 2              Caspian Airlines       Domestic Scheduled Passenger
# 3      Cainiao, opb Aviastar-TU                              Cargo
# 4                             T                     Illegal Flight
# ...                         ...                                ...
# 23514    Handley Page Transport                            Unknown
# 23515    Handley Page Transport                      Demonstration
# 23516    Handley Page Transport  International Scheduled Passenger
# 23517                   Caproni                          Passenger
# 23518                       RAF                               Test
#
#                                        Incident_Category  \
# 0                           Accident | repairable-damage
# 1                           Accident | repairable-damage
# 2                           Accident | repairable-damage
# 3                                   Accident | hull-loss
# 4      Criminal occurrence (sabotage, shoot down) | h...
# ...                                                  ...
# 23514                               Accident | hull-loss
# 23515                               Accident | hull-loss
# 23516                               Accident | hull-loss
# 23517                               Accident | hull-loss
# 23518                               Accident | hull-loss
#
#                                       Incident_Cause(es)  \
# 0      Airplane - Engines, Airplane - Engines - Prop/...
# 1      Airplane - Undercarriage, Airplane - Undercarr...
# 2      Airplane - Undercarriage, Airplane - Undercarr...
# 3      Cargo - Fire/smoke, Result - Damaged on the gr...
# 4                         Result - Damaged on the ground
# ...                                                  ...
# 23514  Result - Emergency, forced landing - Outside a...
# 23515  Result - Emergency, forced landing - Outside a...
# 23516                       Result - CFIT - Level ground
# 23517                                   Info-Unavailable
# 23518                                   Info-Unavailable
#
#           Incident_Location    Aircaft_Damage_Type  \
# 0      near Venetia Mine...            Substantial
# 1          RoatÃ¡n-Juan ...            Substantial
# 2           Isfahan-Shah...            Substantial
# 3           Hangzhou-Xia...              Destroyed
# 4           Machakilha, ...  Damaged beyond repair
# ...                     ...                    ...
# 23514       near El Shereik  Damaged beyond repair
# 23515              ÃstanÃ¥  Damaged beyond repair
# 23516         Golders Green  Damaged beyond repair
# 23517                Verona              Destroyed
# 23518   near Felixtowe RNAS  Damaged beyond repair
#
#                              Date  ...                   Onboard_Total  \
# 0           Monday 3 January 2022  ...    Fatalities: 0 / Occupants: 7
# 1          Tuesday 4 January 2022  ...   Fatalities: 0 / Occupants: 19
# 2        Wednesday 5 January 2022  ...  Fatalities: 0 / Occupants: 116
# 3         Saturday 8 January 2022  ...    Fatalities: 0 / Occupants: 8
# 4       Wednesday 12 January 2022  ...    Fatalities: 0 / Occupants: 0
# ...                           ...  ...                             ...
# 23514  Wednesday 25 February 1920  ...    Fatalities: 0 / Occupants: 4
# 23515      Wednesday 30 June 1920  ...    Fatalities: 0 / Occupants: 2
# 23516    Tuesday 14 December 1920  ...    Fatalities: 4 / Occupants: 8
# 23517      Saturday 2 August 1919  ...  Fatalities: 14 / Occupants: 14
# 23518       Monday 11 August 1919  ...    Fatalities: 1 / Occupants: 7
#
#       Fatalities             Aircaft_First_Flight       Aircraft_Phase  \
# 0              0  1995-05-19  (26 years 8 months)        Landing (LDG)
# 1              0                             1985        Landing (LDG)
# 2              0  1992-09-18  (29 years 4 months)        Landing (LDG)
# 3              0  2002-07-18  (19 years 6 months)       Standing (STD)
# 4              0                              NaN       Standing (STD)
# ...          ...                              ...                  ...
# 23514          0                              NaN        Unknown (UNK)
# 23515          0                             1919       En route (ENR)
# 23516          4                              NaN  Initial climb (ICL)
# 23517         14                             1919       En route (ENR)
# 23518          1           1918-11-11  (9 months)  Initial climb (ICL)
#
#                                        Departure_Airport  \
# 0      Johannesburg-O.R. Tambo International Airport ...
# 1      La Ceiba-Goloson International Airport (LCE/MH...
# 2                      Mashhad Airport (MHD/OIMM) , Iran
# 3      Hangzhou-Xiaoshan International Airport (HGH/Z...
# 4                                                      ?
# ...                                                  ...
# 23514                   Aswan Airport (ASW/HESN) , Egypt
# 23515               Stockholm (unknown airport) , Sweden
# 23516      London-Cricklewood Aerodrome , United Kingdom
# 23517       Venice-Marco Polo Airport (VCE/LIPZ) , Italy
# 23518                   Felixstowe RNAS , United Kingdom
#
#                                      Destination_Airport  Ground_Casualties  \
# 0             Venetia Mine Airport (FAVM) , South Africa                NaN
# 1      RoatÃ¡n-Juan Manuel GÃ¡lvez International Airp...                NaN
# 2      Isfahan-Shahid Beheshti Airport (IFN/OIFM) , Iran                NaN
# 3      Novosibirsk-Tolmachevo Airport (OVB/UNNT) , Ru...                NaN
# 4                                                      ?                NaN
# ...                                                  ...                ...
# 23514          Khartoum-Civil Airport (KRT/HSSS) , Sudan                NaN
# 23515                   Kjeller Air Base (ENKJ) , Norway                NaN
# 23516       Paris-Le Bourget Airport (LBG/LFPB) , France                NaN
# 23517                     Milano-Taliedo Airport , Italy                NaN
# 23518                   Felixstowe RNAS , United Kingdom                NaN
#
#       Collision_Casualties                                Incident_Type  \
# 0                      NaN                                    Accident
# 1                      NaN                                    Accident
# 2                      NaN                                    Accident
# 3                      NaN                                    Accident
# 4                      NaN  Criminal occurrence (sabotage, shoot down)
# ...                    ...                                          ...
# 23514                  NaN                                    Accident
# 23515                  NaN                                    Accident
# 23516                  NaN                                    Accident
# 23517                  NaN                                    Accident
# 23518                  NaN                                    Accident
#
#           Incident_Damage
# 0       repairable-damage
# 1       repairable-damage
# 2       repairable-damage
# 3               hull-loss
# 4               hull-loss
# ...                   ...
# 23514           hull-loss
# 23515           hull-loss
# 23516           hull-loss
# 23517           hull-loss
# 23518           hull-loss
#
# [23012 rows x 25 columns]

# %%
#count occurrence of each value in 'default' column 
df.Fatalities.value_counts()
# Out:
# 0      13791
# 2       1119
# 1       1041
# 3        987
# 4        882
#        ...
# 127        1
# 329        1
# 200        1
# 520        1
# 124        1
# Name: Fatalities, Length: 203, dtype: int64

# %%
df.Fatalities.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0      59.9%
# 2       4.9%
# 1       4.5%
# 3       4.3%
# 4       3.8%
#        ...
# 127     0.0%
# 329     0.0%
# 200     0.0%
# 520     0.0%
# 124     0.0%
# Name: Fatalities, Length: 203, dtype: object

# %%
# sns.catplot(x='Incident_Type', hue='Fatalities', data = df, kind = 'count', height=4, aspect=4)

# %%
# sns.catplot(x='Incident_Damage', hue='Fatalities', data = df, kind = 'count', height=4, aspect=4)

# %%
#mean, median, min, max, standard deviation for numerical fields
df.describe()
# Out:
#          Fatalities
# count  23012.000000
# mean       5.733791
# std       22.433677
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        4.000000
# max     1692.000000

# %%
#Checking for NaN under an entire DataFrame:
df.isnull().values.any()
# Out:
# True

# %%
nulls = data[columns_to_check].isnull().values.any()

# %% [markdown]
# ### Split Test/Train & Modeling

# %%
# df['date_as_string'] = df['Incident_Date'].dt.strftime('%d-%b-%Y')

# %%
# df

# %%
# factors = data.columns[data.columns.get_loc('Aircaft_Model'):data.columns.get_loc('Destination_Airport')+1]
# factors = factors.drop('Fatalities', errors='ignore')
# factors

# %%
# from sklearn.compose import make_column_selector as selector

# # Assuming 'factors' contains categorical column names
# categorical_features = factors  # Assuming factors is a list of categorical column names

# # Preprocessing pipeline for categorical features
# categorical_transformer = Pipeline(steps=[
#     ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
#     ('onehot', OneHotEncoder(handle_unknown='ignore'))
# ])

# # Define preprocessor for categorical columns
# preprocessor = ColumnTransformer(
#     transformers=[
#         ('cat', categorical_transformer, categorical_features)
#     ])

# # Define the classifier
# classifier = RandomForestClassifier(random_state=42)

# # Create a pipeline to bundle preprocessing and classifier
# clf_pipeline = Pipeline(steps=[
#     ('preprocessor', preprocessor),
#     ('classifier', classifier)
# ])

# # Handling class imbalance with RandomOverSampler
# oversample = RandomOverSampler(random_state=42)
# X_train_balanced, y_train_balanced = oversample.fit_resample(X_train, y_train)

# # Fit the classifier with balanced data
# clf_pipeline.fit(X_train_balanced, y_train_balanced)

# # Evaluate the classifier
# accuracy = clf_pipeline.score(X_test, y_test)
# print(f"Accuracy on test set: {accuracy:.2f}")

# %%
# #Confusion matrix
# plot_model(best, plot = 'confusion_matrix')

# %%
# # train logistic regression
# lr = create_model('lr')

# %%
# #Confusion matrix
# plot_model(lr, plot = 'confusion_matrix')

# %%
# #Plot feature importance
# plot_model(lr, plot = "feature")
